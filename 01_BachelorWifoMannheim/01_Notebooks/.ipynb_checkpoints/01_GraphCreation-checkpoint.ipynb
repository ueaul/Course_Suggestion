# %% [markdown]
# # Course-Skill Graph creation for the Bachelor's Program in Business Informatics University of Mannheim
# This notebook contains the code to create the Course-Skill Graph for the Bachelor's Program in Business Informatics of the University of Mannheim

# %% [markdown]
# ## 1. Imports

# %%
import camelot
import pandas as pd
import tableExtraction as te
import graphCreation as gc
import re
import networkx as nx
import matplotlib.pyplot as plt
import sqlite3
# Out:
# hier

# %% [markdown]
# ## 2. Create Graph
# ### 2.1 Extract Course Tables from Module Handbooks

# %%
relevant_courses = te.get_relevant_courses("../02_Ressources/MK_BSc_Wifo_2020_21_Course_Overview.pdf")
courses = te.get_courses("../02_Ressources/MK_BSc_Wifo_2020_21_Courses.pdf")


paths = ["../02_Ressources/Modulkatalog_Nebenfach_BWL.pdf", "../02_Ressources/MK_BSc_Wima_2020_21.pdf"]
end_cells = ["Verwendbarkeit", "Einordnung in Fachsemester"]
coordinates = [[0,0],[0,1]]
courses.extend(te.get_additional_courses(relevant_courses, paths, end_cells, coordinates))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 relevant_courses = te.get_relevant_courses("../02_Ressources/MK_BSc_Wifo_2020_21_Course_Overview.pdf")
# ----> 2 courses = te.get_courses("../02_Ressources/MK_BSc_Wifo_2020_21_Courses.pdf")
#       5 paths = ["../02_Ressources/Modulkatalog_Nebenfach_BWL.pdf", "../02_Ressources/MK_BSc_Wima_2020_21.pdf"]
#       6 end_cells = ["Verwendbarkeit", "Einordnung in Fachsemester"]
#
# File ~\OneDrive - mail.uni-mannheim.de\Uni\Master\Masterarbeit\Course_Suggestion\01_BachelorWifoMannheim\01_Notebooks\tableExtraction.py:254, in get_courses(mainFile)
#     253 def get_courses(mainFile):
# --> 254     tables_raw = camelot.read_pdf(mainFile, pages = "all", strip_text="\n", line_scale=30)
#     255     tables = [table.df for table in tables_raw]
#     256     tables = clean(tables)
#
# File ~\anaconda3\Lib\site-packages\camelot\io.py:113, in read_pdf(filepath, pages, password, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     111 p = PDFHandler(filepath, pages=pages, password=password)
#     112 kwargs = remove_extra(kwargs, flavor=flavor)
# --> 113 tables = p.parse(
#     114     flavor=flavor,
#     115     suppress_stdout=suppress_stdout,
#     116     layout_kwargs=layout_kwargs,
#     117     **kwargs
#     118 )
#     119 return tables
#
# File ~\anaconda3\Lib\site-packages\camelot\handlers.py:169, in PDFHandler.parse(self, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     167 with TemporaryDirectory() as tempdir:
#     168     for p in self.pages:
# --> 169         self._save_page(self.filepath, p, tempdir)
#     170     pages = [os.path.join(tempdir, f"page-{p}.pdf") for p in self.pages]
#     171     parser = Lattice(**kwargs) if flavor == "lattice" else Stream(**kwargs)
#
# File ~\anaconda3\Lib\site-packages\camelot\handlers.py:113, in PDFHandler._save_page(self, filepath, page, temp)
#     111 fpath = os.path.join(temp, f"page-{page}.pdf")
#     112 froot, fext = os.path.splitext(fpath)
# --> 113 p = infile.getPage(page - 1)
#     114 outfile = PdfFileWriter()
#     115 outfile.addPage(p)
#
# File ~\anaconda3\Lib\site-packages\PyPDF2\_reader.py:477, in PdfReader.getPage(self, pageNumber)
#     469 """
#     470 .. deprecated:: 1.28.0
#     471
#     472     Use :code:`reader.pages[page_number]` instead.
#     473 """
#     474 deprecate_with_replacement(
#     475     "reader.getPage(pageNumber)", "reader.pages[page_number]"
#     476 )
# --> 477 return self._get_page(pageNumber)
#
# File ~\anaconda3\Lib\site-packages\PyPDF2\_reader.py:490, in PdfReader._get_page(self, page_number)
#     487 # ensure that we're not trying to access an encrypted PDF
#     488 # assert not self.trailer.has_key(TK.ENCRYPT)
#     489 if self.flattened_pages is None:
# --> 490     self._flatten()
#     491 assert self.flattened_pages is not None, "hint for mypy"
#     492 return self.flattened_pages[page_number]
#
# File ~\anaconda3\Lib\site-packages\PyPDF2\_reader.py:1113, in PdfReader._flatten(self, pages, inherit, indirect_reference)
#    1111         if isinstance(page, IndirectObject):
#    1112             addt["indirect_reference"] = page
# -> 1113         self._flatten(page.get_object(), inherit, **addt)
#    1114 elif t == "/Page":
#    1115     for attr_in, value in list(inherit.items()):
#    1116         # if the page has it's own value, it does not inherit the
#    1117         # parent's value:
#
# File ~\anaconda3\Lib\site-packages\PyPDF2\generic\_base.py:164, in IndirectObject.get_object(self)
#     163 def get_object(self) -> Optional[PdfObject]:
# --> 164     obj = self.pdf.get_object(self)
#     165     if obj is None:
#     166         return None
#
# File ~\anaconda3\Lib\site-packages\PyPDF2\_reader.py:1201, in PdfReader.get_object(self, indirect_reference)
#    1196     return retval
#    1197 if (
#    1198     indirect_reference.generation == 0
#    1199     and indirect_reference.idnum in self.xref_objStm
#    1200 ):
# -> 1201     retval = self._get_object_from_stream(indirect_reference)  # type: ignore
#    1202 elif (
#    1203     indirect_reference.generation in self.xref
#    1204     and indirect_reference.idnum in self.xref[indirect_reference.generation]
#    1205 ):
#    1206     if self.xref_free_entry.get(indirect_reference.generation, {}).get(
#    1207         indirect_reference.idnum, False
#    1208     ):
#
# File ~\anaconda3\Lib\site-packages\PyPDF2\_reader.py:1144, in PdfReader._get_object_from_stream(self, indirect_reference)
#    1142 read_non_whitespace(stream_data)
#    1143 stream_data.seek(-1, 1)
# -> 1144 offset = NumberObject.read_from_stream(stream_data)
#    1145 read_non_whitespace(stream_data)
#    1146 stream_data.seek(-1, 1)
#
# File ~\anaconda3\Lib\site-packages\PyPDF2\generic\_base.py:292, in NumberObject.read_from_stream(stream)
#     290 @staticmethod
#     291 def read_from_stream(stream: StreamType) -> Union["NumberObject", FloatObject]:
# --> 292     num = read_until_regex(stream, NumberObject.NumberPattern)
#     293     if num.find(b".") != -1:
#     294         return FloatObject(num)
#
# File ~\anaconda3\Lib\site-packages\PyPDF2\_utils.py:162, in read_until_regex(stream, regex, ignore_eof)
#     160 m = regex.search(tok)
#     161 if m is not None:
# --> 162     name += tok[: m.start()]
#     163     stream.seek(m.start() - len(tok), 1)
#     164     break
#
# KeyboardInterrupt:

# %% [markdown]
# #export courses
# courses = te.post_fixes(courses)
#
# index = 0
# for course in courses:
#     name = "../03_Courses/" + "Course" + str(index) + ".xlsx"
#     course.to_excel(name, index=False)
#     index += 1

# %%
#import courses

courses = []
for i in range(0,54):
    #Exclude the international courses
    #if not (i == 16) and not (i == 24):
    path = "../03_Courses/Course" + str(i) + ".xlsx"
    df = pd.read_excel(path, dtype=str).fillna('')
    courses.append(df)

# %% [markdown]
# ### 2.2 Creation of Nodes & Edges

# %%
G = nx.DiGraph()

course_nodes = gc.getCourseNodes(courses)
knowledge_nodes = pd.read_excel("../04_Graph/knowledgeAreas.xlsx").values.tolist()
edges_df = pd.read_excel("../04_Graph/edges.xlsx")
edges = edges_df.values.tolist()

# %%
#Create Course Nodes
for node in course_nodes:
    G.add_node(node[0], ECTS=node[1], offering_cycle=node[2], color="grey", type="course", active = False)

#Create Skill Nodes
for i in range(len(knowledge_nodes)):
    if i <= 16:
        G.add_node(knowledge_nodes[i][0], color="blue", type="skill", active = False)
    elif i > 16 and i <= 22:
        G.add_node(knowledge_nodes[i][0], color="green", type="skill", active = False)
    else:
        G.add_node(knowledge_nodes[i][0], color="brown", type="skill", active = False)

#print(G.nodes)

# %%
#Load manually created course -> skill edges
for edge in edges:
   G.add_edge(edge[0], edge[1], active = False)

additional_edges, additional_nodes = gc.complete_edges(courses, edges_df)

for node in additional_nodes:
    G.add_node(node[0], color = node[1], type = node[2], subtype = node[3], amount = node[4], active = False)

for edge in additional_edges:
    if len(edge) <= 2:
        G.add_edge(edge[0], edge[1], active = False)
    else:
        G.add_edge(edge[0], edge[1], weight = edge[2], active = False)
# Out:
# hier

# %%
#Quality Checks for Attribute values

for node, data in G.nodes(data=True):
    print(f"Knoten {node}: name = {data.get('offering_cycle')}")
    #print(data.get('ECTS'))
    #if not (data.get('offering_cycle') == "FWS" or data.get('offering_cycle') =="SSS" or data.get('offering_cycle') == "Continuously"):
        #print(f"Knoten {node}: name = {data.get('offering_cycle')}")
    #print(f"Knoten {node}: name = {data.get('ECTS')}")

#for outgoing, ingoing, data in G.edges(data=True):
#    print(f"{outgoing} -> {ingoing}: weight = {data.get('weight')}")

#for outgoing, ingoing, data in G.edges(data=True):
    #if not data.get("weight") == None:
        #print(f"{outgoing} -> {ingoing}: weight = {data.get('ECTS')}")
    #print(data.get('ECTS'))
# Out:
# Knoten IS 201 Wirtschaftsinformatik I: Einführung und Grundlagen Business Informatics I: Introduction and Foundations: name = FWS
# Knoten IS 202a Wirtschaftsinformatik IIa: Einführung in die Modellierung I: Logik Business Informatics IIa: Foundations of Modeling I: logic: name = SSS
# Knoten IS 202b Wirtschaftsinformatik IIb: Einführung in die Modellierung II: Prozessmodelle Business Informatics IIb: Foundations of Modeling II: process models: name = SSS
# Knoten IS 203 Wirtschaftsinformatik III: Development and Management of Information Systems Business Informatics III: Development and Management of Information Systems: name = FWS
# Knoten IS 204 Wirtschaftsinformatik IV Business Informatics IV: name = SSS
# Knoten CS 301 Formale Grundlagen der Informatik Formal Foundations of Computer Science: name = FWS
# Knoten CS 302 Praktische Informatik I Practical Computer Science I: name = FWS
# Knoten CS 303 Praktische Informatik II Practical Computer Science II: name = SSS
# Knoten CS 304 Programmierpraktikum I Programming Lab I: name = FWS
# Knoten CS 305 Programmierpraktikum II Programming Lab II: name = SSS
# Knoten CS 306 Praktikum Software Engineering Software Engineering Practical: name = SSS
# Knoten CS 307 Algorithmen und Datenstrukturen Algorithms and Data Structures: name = FWS
# Knoten CS 308 Softwaretechnik I Software Engineering I: name = SSS
# Knoten CS 309 Datenbanksysteme I Database Systems I: name = FWS
# Knoten ANA 301 Analysis für Wirtschaftsinformatiker Analysis for Business Informatics: name = SSS
# Knoten Grundlagen der Statistik Foundations of Statistics: name = SSS
# Knoten IS 405 Integrated Information Systems (Wifo) Integrated Information Systems (Wifo): name = FWS
# Knoten CS 405 Künstliche Intelligenz Artificial Intelligence: name = FWS
# Knoten CS 406 Theoretische Informatik Theoretical Computer Science: name = SSS
# Knoten CS 408 Selected Topics in IT-Security Selected Topics in IT-Security: name = Continuously
# Knoten CS 605 GPU-Programmierung GPU Programming: name = Continuously
# Knoten CS 414 Einführung in Data Science Introduction to Data Science: name = FWS
# Knoten MAN 455 Digital Social Innovation Lab "Young Academy" Digital Social Innovation Lab "Young Academy": name = SSS
# Knoten Zeitmanagement Time Management: name = FWS
# Knoten Präsentationskompetenz und Rhetorik Presentation skills and rhetoric: name = SSS
# Knoten Change- und Projektmanagement Projectmanagement: name = FWS
# Knoten Konfliktmanagement: name = SSS
# Knoten Kommunikation im Team: name = SSS
# Knoten Programmierkurs C/C++: name = SSS
# Knoten Sprachkurs: name = Continuously
# Knoten SM 442 Bachelorseminar Prof. Stuckenschmidt Seminar: name = Continuously
# Knoten SM 443 Bachelorseminar Prof. Ponzetto Seminar: name = Continuously
# Knoten SM 444 Bachelorseminar Prof. Bizer Seminar: name = Continuously
# Knoten SM 445 Bachelorseminar Prof. Gemulla Seminar: name = Continuously
# Knoten SM 446 Bachelorseminar Prof. Moerkotte: name = Continuously
# Knoten SM 448 Bachelorseminar Prof. Krause Seminar: name = Continuously
# Knoten SM 449 Bachelorseminar Prof. Atkinson Seminar: name = Continuously
# Knoten SM 450 Bachelorseminar Prof. Armknecht Seminar: name = SSS
# Knoten SM 451 Bachelorseminar Prof. Paulheim Seminar: name = Continuously
# Knoten SM 452 Bachelorseminar Prof. Heinzl Seminar: name = Continuously
# Knoten SM 453 Bachelorseminar Prof. Becker Seminar: name = Continuously
# Knoten SM 454 Bachelorseminar Dr. Rost Seminar: name = Continuously
# Knoten SM 456 Bachelorseminar Dr. Bartelt Seminar: name = Continuously
# Knoten SM 457 Seminar Prof. van der Aa Seminar on Process Analysis: name = FWS
# Knoten BA 450 Bachelor-Abschlussarbeit Bachelor Thesis: name = Continuously
# Knoten Grundlagen des externen Rechnungswesens: name = SSS
# Knoten Internes Rechnungswesen: name = SSS
# Knoten Finanzwirtschaft: name = FWS
# Knoten Marketing: name = FWS
# Knoten Produktion: name = FWS
# Knoten Management: name = SSS
# Knoten MAT 303 Lineare Algebra I Linear Algebra I: name = FWS
# Knoten Recht: name = FWS
# Knoten Grundlagen der Volkswirtschaftslehre: name = FWS
# Knoten Software Development Fundamentals (SDF): name = None
# Knoten Algorithmic Foundations (AL): name = None
# Knoten Foundations of Programming Languages (FPL): name = None
# Knoten Software Engineering (SE): name = None
# Knoten Architecture and Organization (AR): name = None
# Knoten Operating Systems (OS): name = None
# Knoten Networking and Communication (NC): name = None
# Knoten Parallel and Distributed Computing (PDC): name = None
# Knoten Systems Fundamentals (SF): name = None
# Knoten Data Management (DM): name = None
# Knoten Security (SEC): name = None
# Knoten Artificial Intelligence (AI): name = None
# Knoten Graphics and Interactive Techniques (GIT): name = None
# Knoten Human-Computer Interaction (HCI): name = None
# Knoten Specialized Platform Development (SPD): name = None
# Knoten Society, Ethics, and the Profession (SEP): name = None
# Knoten Mathematical and Statistical Foundations (MSF): name = None
# Knoten Information Systems (IS): name = None
# Knoten Accounting and Taxation (AAT): name = None
# Knoten Banking, Finance, and Insurance (FIN): name = None
# Knoten Management (MAN): name = None
# Knoten Marketing and Sales (MKT): name = None
# Knoten Operations Management (OPM): name = None
# Knoten IT Management (ITM): name = None
# Knoten Economics (ECO): name = None
# Knoten Law (LAW): name = None
# Knoten Scientific Work (SW): name = None
# Knoten Business Process Management (BPM): name = None
# Knoten MIN 0: name = None

# %%
pos = nx.spring_layout(G, k=1) 

plt.figure(figsize=(12, 12))

node_colors = [G.nodes[node]['color'] for node in G.nodes()]

nx.draw(G, pos, with_labels=True, node_color=node_colors, font_size=3)

#nx.draw_networkx_labels(G, pos, labels=labels, font_size=10)
plt.savefig("graph.pdf", format="pdf") 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print(G.nodes)
# Out:
# ['IS 201 Wirtschaftsinformatik I: Einführung und Grundlagen Business Informatics I: Introduction and Foundations', 'IS 202a Wirtschaftsinformatik IIa: Einführung in die Modellierung I: Logik Business Informatics IIa: Foundations of Modeling I: logic', 'IS 202b Wirtschaftsinformatik IIb: Einführung in die Modellierung II: Prozessmodelle Business Informatics IIb: Foundations of Modeling II: process models', 'IS 203 Wirtschaftsinformatik III: Development and Management of Information Systems Business Informatics III: Development and Management of Information Systems', 'IS 204 Wirtschaftsinformatik IV Business Informatics IV', 'CS 301 Formale Grundlagen der Informatik Formal Foundations of Computer Science', 'CS 302 Praktische Informatik I Practical Computer Science I', 'CS 303 Praktische Informatik II Practical Computer Science II', 'CS 304 Programmierpraktikum I Programming Lab I', 'CS 305 Programmierpraktikum II Programming Lab II', 'CS 306 Praktikum Software Engineering Software Engineering Practical', 'CS 307 Algorithmen und Datenstrukturen Algorithms and Data Structures', 'CS 308 Softwaretechnik I Software Engineering I', 'CS 309 Datenbanksysteme I Database Systems I', 'ANA 301 Analysis für Wirtschaftsinformatiker Analysis for Business Informatics', 'Grundlagen der Statistik Foundations of Statistics', 'IS 405 Integrated Information Systems (Wifo) Integrated Information Systems (Wifo)', 'CS 405 Künstliche Intelligenz Artificial Intelligence', 'CS 406 Theoretische Informatik Theoretical Computer Science', 'CS 408 Selected Topics in IT-Security Selected Topics in IT-Security', 'CS 605 GPU-Programmierung GPU Programming', 'CS 414 Einführung in Data Science Introduction to Data Science', 'MAN 455 Digital Social Innovation Lab "Young Academy" Digital Social Innovation Lab "Young Academy"', 'Zeitmanagement Time Management', 'Präsentationskompetenz und Rhetorik Presentation skills and rhetoric', 'Change- und Projektmanagement Projectmanagement', 'Konfliktmanagement', 'Kommunikation im Team', 'Programmierkurs C/C++', 'Sprachkurs', 'SM 442 Bachelorseminar Prof. Stuckenschmidt Seminar', 'SM 443 Bachelorseminar Prof. Ponzetto Seminar', 'SM 444 Bachelorseminar Prof. Bizer Seminar', 'SM 445 Bachelorseminar Prof. Gemulla Seminar', 'SM 446 Bachelorseminar Prof. Moerkotte', 'SM 448 Bachelorseminar Prof. Krause Seminar', 'SM 449 Bachelorseminar Prof. Atkinson Seminar', 'SM 450 Bachelorseminar Prof. Armknecht Seminar', 'SM 451 Bachelorseminar Prof. Paulheim Seminar', 'SM 452 Bachelorseminar Prof. Heinzl Seminar', 'SM 453 Bachelorseminar Prof. Becker Seminar', 'SM 454 Bachelorseminar Dr. Rost Seminar', 'SM 456 Bachelorseminar Dr. Bartelt Seminar', 'SM 457 Seminar Prof. van der Aa Seminar on Process Analysis', 'BA 450 Bachelor-Abschlussarbeit Bachelor Thesis', 'Grundlagen des externen Rechnungswesens', 'Internes Rechnungswesen', 'Finanzwirtschaft', 'Marketing', 'Produktion', 'Management', 'MAT 303 Lineare Algebra I Linear Algebra I', 'Recht', 'Grundlagen der Volkswirtschaftslehre', 'Software Development Fundamentals (SDF)', 'Algorithmic Foundations (AL)', 'Foundations of Programming Languages (FPL)', 'Software Engineering (SE)', 'Architecture and Organization (AR)', 'Operating Systems (OS)', 'Networking and Communication (NC)', 'Parallel and Distributed Computing (PDC)', 'Systems Fundamentals (SF)', 'Data Management (DM)', 'Security (SEC)', 'Artificial Intelligence (AI)', 'Graphics and Interactive Techniques (GIT)', 'Human-Computer Interaction (HCI)', 'Specialized Platform Development (SPD)', 'Society, Ethics, and the Profession (SEP)', 'Mathematical and Statistical Foundations (MSF)', 'Information Systems (IS)', 'Accounting and Taxation (AAT)', 'Banking, Finance, and Insurance (FIN)', 'Management (MAN)', 'Marketing and Sales (MKT)', 'Operations Management (OPM)', 'IT Management (ITM)', 'Economics (ECO)', 'Law (LAW)', 'Scientific Work (SW)', 'Business Process Management (BPM)', 'MIN 0']

# %%
# Wähle den gewünschten Node, z.B. node_id
node_id = 'MIN 0'  # Ersetze 'A' durch die ID des gewünschten Nodes

# Finde die Knoten, die mit dem ausgewählten Knoten verbunden sind (eingehend und ausgehend)
incoming_nodes = [n for n in G.predecessors(node_id)]  # Eingehende Knoten
outgoing_nodes = [n for n in G.successors(node_id)]  # Ausgehende Knoten

# Alle relevanten Knoten: der Knoten selbst, eingehende und ausgehende Nachbarn
subgraph_nodes = set([node_id] + incoming_nodes + outgoing_nodes)
#subgraph_nodes = set([node_id] + outgoing_nodes)
#subgraph_nodes = set([node_id] + incoming_nodes)

# Erzeuge den Subgraphen mit den gefundenen Knoten
subgraph = G.subgraph(subgraph_nodes)

# Positionen der Nodes berechnen (für den Subgraphen)
pos = nx.circular_layout(subgraph)

plt.figure(figsize=(12, 12))

# Farben der Nodes für den Subgraphen
node_colors = [subgraph.nodes[node]['color'] for node in subgraph.nodes()]

# Zeichne den Subgraphen
nx.draw(subgraph, pos, with_labels=True, node_color=node_colors, font_size=12)

node_labels = {
    node: f"{node}\nAmount: {subgraph.nodes[node]['amount']}" 
    if 'amount' in subgraph.nodes[node] else node
    for node in subgraph.nodes()
}

offset = 0.05  # Verschiebung der Labels; kann angepasst werden
label_pos = {node: (pos[node][0], pos[node][1] + offset) for node in subgraph.nodes()}

# Zeichne die Labels mit den angepassten Positionen
nx.draw_networkx_labels(subgraph, label_pos, labels=node_labels, font_size=10)

edge_labels = nx.get_edge_attributes(subgraph, 'weight')
nx.draw_networkx_edge_labels(subgraph, pos, edge_labels=edge_labels)


# Speichere das Ergebnis und zeige es an
plt.savefig("subgraph_with_edges.pdf", format="pdf")
plt.show()

# %%
# Positionen der Nodes berechnen (für den Subgraphen)
pos = nx.circular_layout(subgraph)

plt.figure(figsize=(12, 12))

# Farben der Nodes für den Subgraphen
node_colors = [subgraph.nodes[node]['color'] for node in subgraph.nodes()]

# Zeichne die Nodes
nx.draw_networkx_nodes(subgraph, pos, node_color=node_colors)

# Zeichne die gerichteten Kanten
# Hinweis: nx.draw_networkx_edges wird manuell für die Pfeile verwendet
edges = list(subgraph.edges(data=True))
for u, v, data in edges:
    # Zeichne jede Kante mit Gewichtung
    nx.draw_networkx_edges(
        subgraph,
        pos,
        edgelist=[(u, v)],
        arrowstyle='-|>',
        arrowsize=20,
        edge_color='black',
        width=1.5,
    )

# Zeichne Labels für Knoten
node_labels = {
    node: f"{node}\nAmount: {subgraph.nodes[node]['amount']}" 
    if 'amount' in subgraph.nodes[node] else node
    for node in subgraph.nodes()
}

offset = 0.05  # Verschiebung der Labels; kann angepasst werden
label_pos = {node: (pos[node][0], pos[node][1] + offset) for node in subgraph.nodes()}
nx.draw_networkx_labels(subgraph, label_pos, labels=node_labels, font_size=10)

# Zeichne Labels für die Kanten
edge_labels = nx.get_edge_attributes(subgraph, 'weight')
nx.draw_networkx_edge_labels(subgraph, pos, edge_labels=edge_labels)

# Speichere das Ergebnis und zeige es an
plt.savefig("subgraph_with_edges_bidirectional.pdf", format="pdf")
plt.show()

# %%
gc.createPools(G)

# %%
for node in G.nodes:
    if G.nodes[node].get("type") == "course":
        print(node + ": " + G.nodes[node].get("pool", "Kein pool"))
# Out:
# IS 201 Wirtschaftsinformatik I: Einführung und Grundlagen Business Informatics I: Introduction and Foundations: Information Systems
# IS 202a Wirtschaftsinformatik IIa: Einführung in die Modellierung I: Logik Business Informatics IIa: Foundations of Modeling I: logic: Information Systems
# IS 202b Wirtschaftsinformatik IIb: Einführung in die Modellierung II: Prozessmodelle Business Informatics IIb: Foundations of Modeling II: process models: Information Systems
# IS 203 Wirtschaftsinformatik III: Development and Management of Information Systems Business Informatics III: Development and Management of Information Systems: Information Systems
# IS 204 Wirtschaftsinformatik IV Business Informatics IV: Information Systems
# CS 301 Formale Grundlagen der Informatik Formal Foundations of Computer Science: Computer Science
# CS 302 Praktische Informatik I Practical Computer Science I: Computer Science
# CS 303 Praktische Informatik II Practical Computer Science II: Computer Science
# CS 304 Programmierpraktikum I Programming Lab I: Computer Science
# CS 305 Programmierpraktikum II Programming Lab II: Computer Science
# CS 306 Praktikum Software Engineering Software Engineering Practical: Computer Science
# CS 307 Algorithmen und Datenstrukturen Algorithms and Data Structures: Computer Science
# CS 308 Softwaretechnik I Software Engineering I: Computer Science
# CS 309 Datenbanksysteme I Database Systems I: Computer Science
# ANA 301 Analysis für Wirtschaftsinformatiker Analysis for Business Informatics: Mathematics and Statistics
# Grundlagen der Statistik Foundations of Statistics: Mathematics and Statistics
# IS 405 Integrated Information Systems (Wifo) Integrated Information Systems (Wifo): Specialization
# CS 405 Künstliche Intelligenz Artificial Intelligence: Specialization
# CS 406 Theoretische Informatik Theoretical Computer Science: Specialization
# CS 408 Selected Topics in IT-Security Selected Topics in IT-Security: Specialization
# CS 605 GPU-Programmierung GPU Programming: Specialization
# CS 414 Einführung in Data Science Introduction to Data Science: Specialization
# MAN 455 Digital Social Innovation Lab "Young Academy" Digital Social Innovation Lab "Young Academy": Specialization
# Zeitmanagement Time Management: Key Qualification
# Präsentationskompetenz und Rhetorik Presentation skills and rhetoric: Key Qualification
# Change- und Projektmanagement Projectmanagement: Key Qualification
# Konfliktmanagement: Key Qualification Pool
# Kommunikation im Team: Key Qualification Pool
# Programmierkurs C/C++: Key Qualification Pool
# Sprachkurs: Key Qualification Pool
# SM 442 Bachelorseminar Prof. Stuckenschmidt Seminar: Seminar
# SM 443 Bachelorseminar Prof. Ponzetto Seminar: Seminar
# SM 444 Bachelorseminar Prof. Bizer Seminar: Seminar
# SM 445 Bachelorseminar Prof. Gemulla Seminar: Seminar
# SM 446 Bachelorseminar Prof. Moerkotte: Seminar
# SM 448 Bachelorseminar Prof. Krause Seminar: Seminar
# SM 449 Bachelorseminar Prof. Atkinson Seminar: Seminar
# SM 450 Bachelorseminar Prof. Armknecht Seminar: Seminar
# SM 451 Bachelorseminar Prof. Paulheim Seminar: Seminar
# SM 452 Bachelorseminar Prof. Heinzl Seminar: Seminar
# SM 453 Bachelorseminar Prof. Becker Seminar: Seminar
# SM 454 Bachelorseminar Dr. Rost Seminar: Seminar
# SM 456 Bachelorseminar Dr. Bartelt Seminar: Seminar
# SM 457 Seminar Prof. van der Aa Seminar on Process Analysis: Seminar
# BA 450 Bachelor-Abschlussarbeit Bachelor Thesis: Thesis
# Grundlagen des externen Rechnungswesens: Business|Elective
# Internes Rechnungswesen: Business|Elective
# Finanzwirtschaft: Business|Elective
# Marketing: Business|Elective
# Produktion: Business|Elective
# Management: Business|Elective
# MAT 303 Lineare Algebra I Linear Algebra I: Mathematics and Statistics
# Recht: Elective
# Grundlagen der Volkswirtschaftslehre: Elective

# %% [markdown]
# ### 2.3 Matching Graph Names to Database Names

# %%
#Match Course Names between Graph and Database

df_courseNames = pd.read_csv("../02_Ressources/DB_CourseNames.csv")

conn = sqlite3.connect('DB_CourseNames.db')
cursor = conn.cursor()

df_courseNames.to_sql('course_names', conn, if_exists='replace', index=False)

graph_courseNames = []
for course in courses:
    graph_courseNames.append(gc.mapGraphToDB_courseName(course))

matching_results = []

for graph_courseName in graph_courseNames:
    query = "SELECT kurs FROM course_names WHERE ? LIKE kurs || '%'" 
    cursor.execute(query, (graph_courseName,))
    results = cursor.fetchall()
    
    results_string = ', '.join([str(result[0]) for result in results])
    matching_results.append(graph_courseName + " matches: " + results_string)


query = "SELECT kurs FROM course_names" 
cursor.execute(query)
results = cursor.fetchall()
    

#for line in results:
#    print(line[0])

#print("\n")

for course_match in matching_results:
    if re.match(r".*matches: $", course_match):
        print(course_match)

conn.close()
# Out:
# SM 451 Bachelorseminar Prof. Paulheim Seminar matches:
# BA 450 Bachelor-Abschlussarbeit Bachelor Thesis matches:

# %% [markdown]
# ### 2.4 Weight Course -> Skill Edges

# %%
#Export graph to run weighting scripts externally
nx.write_graphml(G, "CourseSkillGraph.graphml")

# %%
course_skill_weights_df = pd.read_excel("../04_Graph/CourseSkillWeights.xlsx")
course_skill_weights = course_skill_weights_df.values.tolist()

for weight in course_skill_weights:
    G.edges[weight[1], weight[2]]["weight"] = weight[0]/100

# %%
#Adjust 0 weights for course suggestion algorithm

smallestWeight = 1000
for edge in G.edges:
    if G.nodes[edge[0]].get("type") == "course" and G.nodes[edge[1]].get("type") == "skill":
        weight = G.edges[edge].get("weight")
        if weight < smallestWeight and weight > 0:
            smallestWeight = weight

print(smallestWeight)

for edge in G.edges:
    if G.nodes[edge[0]].get("type") == "course" and G.nodes[edge[1]].get("type") == "skill":
        weight = G.edges[edge].get("weight")
        if weight == 0:
            G.edges[edge]["weight"] = 0.01

smallestWeight = 1000
for edge in G.edges:
    if G.nodes[edge[0]].get("type") == "course" and G.nodes[edge[1]].get("type") == "skill":
        weight = G.edges[edge].get("weight")
        if weight < smallestWeight and weight > 0:
            smallestWeight = weight

print(smallestWeight)
# Out:
# 0.09959725183605798
# 0.01

# %%
#Export graph with course -> skill weights as needed for the skill -> course weighting script
nx.write_graphml(G, "CourseSkillGraph.graphml")

# %% [markdown]
# ### 2.5 Weight Skill -> Course Edges

# %%
skill_course_weights_df = pd.read_excel("../04_Graph/SkillCourseWeights.xlsx")
skill_course_weights = skill_course_weights_df.values.tolist()

for weight in skill_course_weights:
    G.edges[weight[1], weight[2]]["weight"] = weight[0]

# %%
#Export graph with all weighted edges
nx.write_graphml(G, "CourseSkillGraph_Bachelor.graphml")
