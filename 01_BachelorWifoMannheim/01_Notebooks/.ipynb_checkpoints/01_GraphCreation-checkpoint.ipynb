# %% [markdown]
# # Course-Skill Graph creation for the Bachelor's Program in Business Informatics University of Mannheim
# This notebook contains the code to create the Course-Skill Graph for the Bachelor's Program in Business Informatics of the University of Mannheim

# %% [markdown]
# ## 1. Imports

# %%
import camelot
import pandas as pd
import tableExtraction as te
import graphCreation as gc
import re
import networkx as nx
import matplotlib.pyplot as plt
import sqlite3

# %% [markdown]
# ## 2. Create Graph
# ### 2.1 Extract Course Tables from Module Handbooks
# This part covers the extraction of the relevant courses from the module catalogs. The courses are extracted as Pandas DataFrames and stored in csv files.

# %%
relevant_courses = te.get_relevant_courses("../02_Ressources/MK_BSc_Wifo_2020_21_Course_Overview.pdf")
courses = te.get_courses("../02_Ressources/MK_BSc_Wifo_2020_21_Courses.pdf")


paths = ["../02_Ressources/Modulkatalog_Nebenfach_BWL.pdf", "../02_Ressources/MK_BSc_Wima_2020_21.pdf"]
end_cells = ["Verwendbarkeit", "Einordnung in Fachsemester"]
coordinates = [[0,0],[0,1]]
courses.extend(te.get_additional_courses(relevant_courses, paths, end_cells, coordinates))
# Out:
# C:\Users\Paul\anaconda3\envs\master_thesis\lib\site-packages\camelot\utils.py:740: UserWarning:   (541.47, 544.182) does not lie in column range (65.52538683491369, 541.3654737903225)
#   warnings.warn(
# C:\Users\Paul\anaconda3\envs\master_thesis\lib\site-packages\camelot\utils.py:740: UserWarning:   (541.47, 544.182) does not lie in column range (65.52547473292196, 541.3654737903225)
#   warnings.warn(
# C:\Users\Paul\anaconda3\envs\master_thesis\lib\site-packages\camelot\utils.py:740: UserWarning:   (535.58, 538.292) does not lie in column range (71.03522406889036, 535.0440545877398)
#   warnings.warn(
# C:\Users\Paul\anaconda3\envs\master_thesis\lib\site-packages\camelot\utils.py:740: UserWarning:     (535.58, 538.292) does not lie in column range (71.03147798266829, 535.0440548166061)
#   warnings.warn(
# C:\Users\Paul\anaconda3\envs\master_thesis\lib\site-packages\camelot\utils.py:740: UserWarning:   (535.58, 538.292) does not lie in column range (71.03147798266829, 535.0440548166061)
#   warnings.warn(

# %%
#Everything in this cell is commented out to avoid the manually edited csv files from being overwritten

#Export course DataFrames to .csv files
#courses = te.post_fixes(courses)

#index = 0
#for course in courses:
    #name = "../03_Courses/" + "Course" + str(index) + ".xlsx"
    #course.to_excel(name, index=False)
    #index += 1

# %%
#Import courses from the manually edited csv files and store them as DataFrames

courses = []
for i in range(0,54):
    #Exclude the international courses
    #if not (i == 16) and not (i == 24):
    path = "../03_Courses/Course" + str(i) + ".xlsx"
    df = pd.read_excel(path, dtype=str).fillna('')
    courses.append(df)

# %% [markdown]
# ### 2.2 Creation of Nodes & Edges
# This part covers the creation of the nodes and edges of the Course-Skill Graph.

# %%
#Create an empty NetworkX Graph
G = nx.DiGraph()

#Extract course names together with the ECTS points they credit and their offering cycle from the DataFrames and store the information in a list
course_nodes = gc.getCourseNodes(courses)

#Import the names of the skill nodes and store them in a list
knowledge_nodes = pd.read_excel("../04_Graph/knowledgeAreas.xlsx").values.tolist()

#Import the manually created course -> skill edges of the graph as a DataFrame with the columns "Outgoing" and "Incoming"
edges_df = pd.read_excel("../04_Graph/edges.xlsx")

#Translate the DataFrame representing the edges into a list
edges = edges_df.values.tolist()

# %%
#Create the course nodes and add them to the graph
for node in course_nodes:
    G.add_node(node[0], ECTS=node[1], offering_cycle=node[2], color="grey", type="course", active = False)

#Create the skill nodes and add them to the graph
for i in range(len(knowledge_nodes)):
    if i <= 16:
        G.add_node(knowledge_nodes[i][0], color="blue", type="skill", active = False)
    elif i > 16 and i <= 22:
        G.add_node(knowledge_nodes[i][0], color="green", type="skill", active = False)
    else:
        G.add_node(knowledge_nodes[i][0], color="red", type="skill", active = False)

# %%
#Add the course -> skill edges to the graph
for edge in edges:
   G.add_edge(edge[0], edge[1], active = False)

#Create the skill -> course edges and all edges representing prerequisite relationships
additional_edges, prerequiste_nodes = gc.complete_edges(courses, edges_df)

#Add prerequiste nodes to the graph
for node in prerequiste_nodes:
    G.add_node(node[0], color = node[1], type = node[2], subtype = node[3], amount = node[4], active = False)

#Add skill -> course edges and all edges representing prerequisite relationships to the graph
for edge in additional_edges:
    if len(edge) <= 2:
        G.add_edge(edge[0], edge[1], active = False)
    else:
        G.add_edge(edge[0], edge[1], weight = edge[2], active = False)

# %%
#Quality Checks for Attribute values. Commented out as all checks are fulfilled

#for node, data in G.nodes(data=True):
    #print(f"Knoten {node}: name = {data.get('offering_cycle')}")
    #print(data.get('ECTS'))
    #if not (data.get('offering_cycle') == "FWS" or data.get('offering_cycle') =="SSS" or data.get('offering_cycle') == "Continuously"):
        #print(f"Knoten {node}: name = {data.get('offering_cycle')}")
    #print(f"Knoten {node}: name = {data.get('ECTS')}")

#for outgoing, ingoing, data in G.edges(data=True):
#    print(f"{outgoing} -> {ingoing}: weight = {data.get('weight')}")

#for outgoing, ingoing, data in G.edges(data=True):
    #if not data.get("weight") == None:
        #print(f"{outgoing} -> {ingoing}: weight = {data.get('ECTS')}")
    #print(data.get('ECTS'))

# %%
#Export Course-Skill Graph as a PDF file

pos = nx.spring_layout(G, k=1) 
plt.figure(figsize=(12, 12))

node_colors = [G.nodes[node]['color'] for node in G.nodes()]
nx.draw(G, pos, with_labels=True, node_color=node_colors, font_size=3)

plt.savefig("Outputs/Course-Skill_Graph_Bachelor.pdf", format="pdf") 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Script for visualizing individual nodes

#Insert Name of the node to visualize
node_id = 'MIN 0' 

#Get incoming and outgoing edges of the node
incoming_nodes = [n for n in G.predecessors(node_id)] 
outgoing_nodes = [n for n in G.successors(node_id)] 

#Uncomment the desired edges that should be included in the visualization
subgraph_nodes = set([node_id] + incoming_nodes + outgoing_nodes)
#subgraph_nodes = set([node_id] + outgoing_nodes)
#subgraph_nodes = set([node_id] + incoming_nodes)

#Create the plot
subgraph = G.subgraph(subgraph_nodes)
pos = nx.circular_layout(subgraph)
plt.figure(figsize=(12, 12))

node_colors = [subgraph.nodes[node]['color'] for node in subgraph.nodes()]
nx.draw(subgraph, pos, with_labels=True, node_color=node_colors, font_size=12)
node_labels = {
    node: f"{node}\nAmount: {subgraph.nodes[node]['amount']}" 
    if 'amount' in subgraph.nodes[node] else node
    for node in subgraph.nodes()
}

offset = 0.05 
label_pos = {node: (pos[node][0], pos[node][1] + offset) for node in subgraph.nodes()}
nx.draw_networkx_labels(subgraph, label_pos, labels=node_labels, font_size=10)
edge_labels = nx.get_edge_attributes(subgraph, 'weight')
nx.draw_networkx_edge_labels(subgraph, pos, edge_labels=edge_labels)

plt.savefig("Outputs/Node_Visualization.pdf", format="pdf")
plt.show()

# %%
#Assign the course pool attribute
gc.createPools(G)

#Check if all course nodes are assigned to a course pool
for node in G.nodes:
    if G.nodes[node].get("type") == "course":
        print(node + ": " + G.nodes[node].get("pool", "Kein pool"))
# Out:
# IS 201 Wirtschaftsinformatik I: Einführung und Grundlagen Business Informatics I: Introduction and Foundations: Fundamentals Information Systems
# IS 202a Wirtschaftsinformatik IIa: Einführung in die Modellierung I: Logik Business Informatics IIa: Foundations of Modeling I: logic: Fundamentals Information Systems
# IS 202b Wirtschaftsinformatik IIb: Einführung in die Modellierung II: Prozessmodelle Business Informatics IIb: Foundations of Modeling II: process models: Fundamentals Information Systems
# IS 203 Wirtschaftsinformatik III: Development and Management of Information Systems Business Informatics III: Development and Management of Information Systems: Fundamentals Information Systems
# IS 204 Wirtschaftsinformatik IV Business Informatics IV: Fundamentals Information Systems
# CS 301 Formale Grundlagen der Informatik Formal Foundations of Computer Science: Fundamentals Computer Science
# CS 302 Praktische Informatik I Practical Computer Science I: Fundamentals Computer Science
# CS 303 Praktische Informatik II Practical Computer Science II: Fundamentals Computer Science
# CS 304 Programmierpraktikum I Programming Lab I: Fundamentals Computer Science
# CS 305 Programmierpraktikum II Programming Lab II: Fundamentals Computer Science
# CS 306 Praktikum Software Engineering Software Engineering Practical: Fundamentals Computer Science
# CS 307 Algorithmen und Datenstrukturen Algorithms and Data Structures: Fundamentals Computer Science
# CS 308 Softwaretechnik I Software Engineering I: Fundamentals Computer Science
# CS 309 Datenbanksysteme I Database Systems I: Fundamentals Computer Science
# ANA 301 Analysis für Wirtschaftsinformatiker Analysis for Business Informatics: Fundamentals Mathematics and Statistics
# Grundlagen der Statistik Foundations of Statistics: Fundamentals Mathematics and Statistics
# IS 405 Integrated Information Systems (Wifo) Integrated Information Systems (Wifo): Specialization Courses
# CS 405 Künstliche Intelligenz Artificial Intelligence: Specialization Courses
# CS 406 Theoretische Informatik Theoretical Computer Science: Specialization Courses
# CS 408 Selected Topics in IT-Security Selected Topics in IT-Security: Specialization Courses
# CS 605 GPU-Programmierung GPU Programming: Specialization Courses
# CS 414 Einführung in Data Science Introduction to Data Science: Specialization Courses
# MAN 455 Digital Social Innovation Lab "Young Academy" Digital Social Innovation Lab "Young Academy": Specialization Courses
# Zeitmanagement Time Management: Key Qualifications
# Präsentationskompetenz und Rhetorik Presentation skills and rhetoric: Key Qualifications
# Change- und Projektmanagement Projectmanagement: Key Qualifications
# Konfliktmanagement: Key Qualifications Pool
# Kommunikation im Team: Key Qualifications Pool
# Programmierkurs C/C++: Key Qualifications Pool
# Sprachkurs: Key Qualifications Pool
# SM 442 Bachelorseminar Prof. Stuckenschmidt Seminar: Seminars
# SM 443 Bachelorseminar Prof. Ponzetto Seminar: Seminars
# SM 444 Bachelorseminar Prof. Bizer Seminar: Seminars
# SM 445 Bachelorseminar Prof. Gemulla Seminar: Seminars
# SM 446 Bachelorseminar Prof. Moerkotte: Seminars
# SM 448 Bachelorseminar Prof. Krause Seminar: Seminars
# SM 449 Bachelorseminar Prof. Atkinson Seminar: Seminars
# SM 450 Bachelorseminar Prof. Armknecht Seminar: Seminars
# SM 451 Bachelorseminar Prof. Paulheim Seminar: Seminars
# SM 452 Bachelorseminar Prof. Heinzl Seminar: Seminars
# SM 453 Bachelorseminar Prof. Becker Seminar: Seminars
# SM 454 Bachelorseminar Dr. Rost Seminar: Seminars
# SM 456 Bachelorseminar Dr. Bartelt Seminar: Seminars
# SM 457 Seminar Prof. van der Aa Seminar on Process Analysis: Seminars
# BA 450 Bachelor-Abschlussarbeit Bachelor Thesis: Thesis
# Grundlagen des externen Rechnungswesens: Fundamentals Business Administration|Elective Courses|Specialization Courses
# Internes Rechnungswesen: Fundamentals Business Administration|Elective Courses|Specialization Courses
# Finanzwirtschaft: Fundamentals Business Administration|Elective Courses|Specialization Courses
# Marketing: Fundamentals Business Administration|Elective Courses|Specialization Courses
# Produktion: Fundamentals Business Administration|Elective Courses|Specialization Courses
# Management: Fundamentals Business Administration|Elective Courses|Specialization Courses
# MAT 303 Lineare Algebra I Linear Algebra I: Fundamentals Mathematics and Statistics
# Recht: Elective Courses
# Grundlagen der Volkswirtschaftslehre: Elective Courses

# %% [markdown]
# ### 2.3 Matching Graph Names to Database Names
# This part covers the process of matching the course names in the module catalog / graph to the course names in the database.

# %%
#Match Course Names between Graph and Database

df_courseNames = pd.read_csv("../02_Ressources/DB_CourseNames.csv")

conn = sqlite3.connect('Course_Matching/DB_CourseNames.db')
cursor = conn.cursor()

df_courseNames.to_sql('course_names', conn, if_exists='replace', index=False)

graph_courseNames = []
for course in courses:
    graph_courseNames.append(gc.mapGraphToDB_courseName(course))

matching_results = []

for graph_courseName in graph_courseNames:
    query = "SELECT kurs FROM course_names WHERE ? LIKE Course || '%'" 
    cursor.execute(query, (graph_courseName,))
    results = cursor.fetchall()
    
    results_string = ', '.join([str(result[0]) for result in results])
    matching_results.append(graph_courseName + " matches: " + results_string)


query = "SELECT kurs FROM course_names" 
cursor.execute(query)
results = cursor.fetchall()
    

#for line in results:
#    print(line[0])

#print("\n")

for course_match in matching_results:
    if re.match(r".*matches: $", course_match):
        print(course_match)

conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[11], line 18
#      16 for graph_courseName in graph_courseNames:
#      17     query = "SELECT kurs FROM course_names WHERE ? LIKE kurs || '%'"
# ---> 18     cursor.execute(query, (graph_courseName,))
#      19     results = cursor.fetchall()
#      21     results_string = ', '.join([str(result[0]) for result in results])
#
# OperationalError: no such column: kurs

# %% [markdown]
# ### 2.4 Weight Course -> Skill Edges

# %%
#Export graph to run weighting scripts externally
nx.write_graphml(G, "CourseSkillGraph_Bachelor.graphml")

# %%
course_skill_weights_df = pd.read_excel("../04_Graph/CourseSkillWeights_Bachelor.xlsx")
course_skill_weights = course_skill_weights_df.values.tolist()

for weight in course_skill_weights:
    G.edges[weight[1], weight[2]]["weight"] = weight[0]/100

# %%
#Get smallest weight

smallestWeight = 1000
for edge in G.edges:
    if G.nodes[edge[0]].get("type") == "course" and G.nodes[edge[1]].get("type") == "skill":
        weight = G.edges[edge].get("weight")
        if weight < smallestWeight and weight > 0:
            smallestWeight = weight

print(smallestWeight)
# Out:
# 0.001

# %%
#Export graph with course -> skill weights as needed for the skill -> course weighting script
nx.write_graphml(G, "CourseSkillGraph_Bachelor.graphml")

# %% [markdown]
# ### 2.5 Weight Skill -> Course Edges

# %%
skill_course_weights_df = pd.read_excel("../04_Graph/SkillCourseWeights_Bachelor.xlsx")
skill_course_weights = skill_course_weights_df.values.tolist()

for weight in skill_course_weights:
    G.edges[weight[1], weight[2]]["weight"] = weight[0]

# %%
#Export graph with all weighted edges
nx.write_graphml(G, "CourseSkillGraph_Bachelor.graphml")
