# %% [markdown]
# # Course-Skill Graph creation for the Master's Program in Business Informatics University of Mannheim
# This notebook contains the code to create the Course-Skill Graph for the Master's Program in Business Informatics of the University of Mannheim

# %% [markdown]
# ## 1. Imports

# %%
import camelot
import pandas as pd
import tableExtraction as te
import graphCreation as gc
import re
import networkx as nx
import matplotlib.pyplot as plt
import sqlite3

# %% [markdown]
# ## 2. Create Graph
# ### 2.1 Extract Course Tables from Module Handbooks

# %%
relevant_courses = te.get_relevant_courses("../02_Ressources/MK_MSc_Wifo_neue_PO_2020_21_CourseOverview.pdf")
courses = te.get_courses("../02_Ressources/MK_MSc_Wifo_neue_PO_2020_21_Courses.pdf")


paths = ["../02_Ressources/Modulkatalog_MMM_Deutsch_abHWS2020.pdf"]
end_cells = [r"Range of application|Verwendbarkeit"]
coordinates = [[0,0]]
bwl_range = [["ACC", "TAX", "FIN", "MAN", "MKT", "OPM"], ["5", "6"]]
courses.extend(te.get_additional_courses(relevant_courses, paths, end_cells, coordinates, bwl_range))
#courses_BWL = te.get_additional_courses(relevant_courses, paths, end_cells, coordinates, bwl_range)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 relevant_courses = te.get_relevant_courses("../02_Ressources/MK_MSc_Wifo_neue_PO_2020_21_CourseOverview.pdf")
# ----> 2 courses = te.get_courses("../02_Ressources/MK_MSc_Wifo_neue_PO_2020_21_Courses.pdf")
#       5 paths = ["../02_Ressources/Modulkatalog_MMM_Deutsch_abHWS2020.pdf"]
#       6 end_cells = [r"Range of application|Verwendbarkeit"]
#
# File ~\OneDrive - mail.uni-mannheim.de\Uni\Master\Masterarbeit\Course_Suggestion\02_MasterWifoMannheim\01_Notebooks\tableExtraction.py:251, in get_courses(mainFile)
#     250 def get_courses(mainFile):
# --> 251     tables_raw = camelot.read_pdf(mainFile, pages = "all", strip_text="\n", line_scale=30)
#     252     tables = [table.df for table in tables_raw]
#     253     tables = clean(tables)
#
# File ~\anaconda3\envs\master_thesis\lib\site-packages\camelot\io.py:113, in read_pdf(filepath, pages, password, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     111 p = PDFHandler(filepath, pages=pages, password=password)
#     112 kwargs = remove_extra(kwargs, flavor=flavor)
# --> 113 tables = p.parse(
#     114     flavor=flavor,
#     115     suppress_stdout=suppress_stdout,
#     116     layout_kwargs=layout_kwargs,
#     117     **kwargs
#     118 )
#     119 return tables
#
# File ~\anaconda3\envs\master_thesis\lib\site-packages\camelot\handlers.py:176, in PDFHandler.parse(self, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     174     parser = Lattice(**kwargs) if flavor == "lattice" else Stream(**kwargs)
#     175     for p in pages:
# --> 176         t = parser.extract_tables(
#     177             p, suppress_stdout=suppress_stdout, layout_kwargs=layout_kwargs
#     178         )
#     179         tables.extend(t)
#     180 return TableList(sorted(tables))
#
# File ~\anaconda3\envs\master_thesis\lib\site-packages\camelot\parsers\lattice.py:421, in Lattice.extract_tables(self, filename, suppress_stdout, layout_kwargs)
#     416         warnings.warn(
#     417             "No tables found on {}".format(os.path.basename(self.rootname))
#     418         )
#     419     return []
# --> 421 self.backend.convert(self.filename, self.imagename)
#     423 self._generate_table_bbox()
#     425 _tables = []
#
# File ~\anaconda3\envs\master_thesis\lib\site-packages\camelot\backends\ghostscript_backend.py:47, in GhostscriptBackend.convert(self, pdf_path, png_path, resolution)
#      36 import ghostscript
#      38 gs_command = [
#      39     "gs",
#      40     "-q",
#    (...)
#      45     pdf_path,
#      46 ]
# ---> 47 ghostscript.Ghostscript(*gs_command)
#
# File ~\anaconda3\envs\master_thesis\lib\site-packages\ghostscript\__init__.py:87, in Ghostscript.__init__(self, stdin, stdout, stderr, *args)
#      85 try:
#      86     self.set_stdio(stdin, stdout, stderr)
# ---> 87     rc = gs.init_with_args(self._instance, args)
#      88     if rc == gs.e_Info:
#      89         raise PleaseDisplayUsage()
#
# File ~\anaconda3\envs\master_thesis\lib\site-packages\ghostscript\_gsprint.py:286, in init_with_args(instance, argv)
#     284 ArgArray = c_char_p * len(argv)
#     285 c_argv = ArgArray(*argv)
# --> 286 rc = libgs.gsapi_init_with_args(instance, len(argv), c_argv)
#     287 if rc not in (0, e_Quit, e_Info):
#     288     raise GhostscriptError(rc)
#
# KeyboardInterrupt:

# %% [markdown]
# courses = te.post_fixes(courses)
#
# index = 0
# for course in courses:
#     name = "../03_Courses/" + "Course" + str(index) + ".xlsx"
#     course.to_excel(name, index=False)
#     index += 1

# %%
#import courses

courses = []
for i in range(0,173):
    path = "../03_Courses/Course" + str(i) + ".xlsx"
    df = pd.read_excel(path, dtype=str).fillna('')
    courses.append(df)

# %% [markdown]
# ### 2.2 Creation of Nodes & Edges

# %%
G = nx.DiGraph()

course_nodes = gc.getCourseNodes(courses)
knowledge_nodes = pd.read_excel("../04_Graph/knowledgeAreas.xlsx").values.tolist()
edges_df = pd.read_excel("../04_Graph/edges.xlsx")
edges = edges_df.values.tolist()

# %%
#Create Course Nodes
for node in course_nodes:
    G.add_node(node[0], ECTS=node[1], offering_cycle=node[2], color="grey", type="course", active = False)

#Create Skill Nodes
for i in range(len(knowledge_nodes)):
    if i <= 16:
        G.add_node(knowledge_nodes[i][0], color="blue", type="skill", active = False)
    elif i > 16 and i <= 22:
        G.add_node(knowledge_nodes[i][0], color="green", type="skill", active = False)
    else:
        G.add_node(knowledge_nodes[i][0], color="brown", type="skill", active = False)

names = []

# %%
#Load manually created course -> skill edges
for edge in edges:
   G.add_edge(edge[0], edge[1], active = False)

additional_edges, additional_nodes = gc.complete_edges(courses, edges_df)

for node in additional_nodes:
    G.add_node(node[0], color = node[1], type = node[2], subtype = node[3], amount = node[4], active = False)

for edge in additional_edges:
    if len(edge) <= 2:
        G.add_edge(edge[0], edge[1], active = False)
    else:
        G.add_edge(edge[0], edge[1], weight = edge[2], active = False)

# %%
# Get Min Nodes for parallel attendance
node_id = 'OPM 601 Supply Chain Management'  
node_id = 'OPM 661 Business Analytics: Robust Planning in Stochastic Systems'  
node_id = 'OPM 682 Revenue Management'  
node_id = 'CS 500 Advanced Software Engineering'  

outgoing_nodes = [n for n in G.successors(node_id)]
incoming_nodes = [n for n in G.predecessors(node_id)]  
subgraph_nodes = set([node_id] + incoming_nodes + outgoing_nodes)
subgraph = G.subgraph(subgraph_nodes)

print(outgoing_nodes)

pos = nx.circular_layout(subgraph)
plt.figure(figsize=(12, 12))
node_colors = [subgraph.nodes[node]['color'] for node in subgraph.nodes()]
nx.draw(subgraph, pos, with_labels=True, node_color=node_colors, font_size=12)

edge_labels = nx.get_edge_attributes(subgraph, 'weight')
nx.draw_networkx_edge_labels(subgraph, pos, edge_labels=edge_labels)

plt.show()
# Out:
# ['Software Engineering (SE)']

# %%
#Set weights for parallel prerequisite course dependency
G.edges["FIN 540 Corporate Finance I - Lecture (Capital Structure, Cost of Capital and Valuation)",
"FIN 541 Corporate Finance I - Case Study (Capital Structure, Cost of Capital and Valuation)"]["weight"] = 2

G.edges["IS 512 IT Management in the Digital Age", "IS 513 Applied IT Management in the Digital Age"]["weight"] = 2

G.edges["IS 615 Design Thinking and Lean Development in Enterprise Software Development", 
"IS 613 Applied Project in Design Thinking and Lean Software Development"]["weight"] = 2

G.edges["MIN 10", "OPM 601 Supply Chain Management"]["weight"] = 2

G.edges["MIN 11", "OPM 661 Business Analytics: Robust Planning in Stochastic Systems"]["weight"] = 2

G.edges["MIN 12", "OPM 682 Revenue Management"]["weight"] = 2

# %%
#Add complex prerequisite dependencies

#ACC 626 
G.add_node("MIN 13", color = "white", type = "prerequisite", subtype = "MIN", amount = 1, active = False)
G.add_node("MIN 14", color = "white", type = "prerequisite", subtype = "MIN", amount = 2, active = False)
G.add_edge("MIN 13", "ACC 626 Transaction Accounting", weight = 1, active = False)
G.add_edge("ACC 520 IFRS Accounting and Capital Markets", "MIN 13", weight = 1, active = False)
G.add_edge("ACC 530 Group Accounting", "MIN 13", weight = 1, active = False)
G.add_edge("MIN 14", "MIN 13", weight = 1, active = False)
G.add_edge("ACC 510 Jahresabschluss", "MIN 14", weight = 1, active = False)
G.add_edge("ACC 540 Financial Statement Analysis & Equity Valuation", "MIN 14", weight = 1, active = False)
G.add_edge("ACC 560 Managerial Accounting", "MIN 14", weight = 1, active = False)

#ACC 628 
G.add_node("MIN 15", color = "white", type = "prerequisite", subtype = "MIN", amount = 1, active = False)
G.add_node("MIN 16", color = "white", type = "prerequisite", subtype = "MIN", amount = 2, active = False)
G.add_edge("MIN 15", "ACC 628 Selected Issues in IFRS Accounting", weight = 1, active = False)
G.add_edge("ACC 520 IFRS Accounting and Capital Markets", "MIN 15", weight = 1, active = False)
G.add_edge("MIN 16", "MIN 15", weight = 1, active = False)
G.add_edge("ACC 510 Jahresabschluss", "MIN 16", weight = 1, active = False)
G.add_edge("ACC 530 Group Accounting", "MIN 16", weight = 1, active = False)
G.add_edge("ACC 540 Financial Statement Analysis & Equity Valuation", "MIN 16", weight = 1, active = False)
G.add_edge("ACC 560 Managerial Accounting", "MIN 16", weight = 1, active = False)

#ACC 632 
G.add_node("MIN 17", color = "white", type = "prerequisite", subtype = "MIN", amount = 1, active = False)
G.add_node("MIN 18", color = "white", type = "prerequisite", subtype = "MIN", amount = 2, active = False)
G.add_edge("MIN 17", "ACC 632 Konzernrechnungslegungspraxis", weight = 1, active = False)
G.add_edge("ACC 530 Group Accounting", "MIN 17", weight = 1, active = False)
G.add_edge("MIN 18", "MIN 17", weight = 1, active = False)
G.add_edge("ACC 510 Jahresabschluss", "MIN 18", weight = 1, active = False)
G.add_edge("ACC 520 IFRS Accounting and Capital Markets", "MIN 18", weight = 1, active = False)
G.add_edge("ACC 540 Financial Statement Analysis & Equity Valuation", "MIN 18", weight = 1, active = False)
G.add_edge("ACC 560 Managerial Accounting", "MIN 18", weight = 1, active = False)

# %%
#Quality Checks for Attribute values

for node, data in G.nodes(data=True):
    #print(f"Knoten {node}: name = {data.get('offering_cycle')}")
    print(data.get('offering_cycle'))
    #if not (data.get('offering_cycle') == "FWS" or data.get('offering_cycle') =="SSS" or data.get('offering_cycle') == "Continuously"):
        #print(f"Knoten {node}: name = {data.get('offering_cycle')}")
    #print(f"Knoten {node}: name = {data.get('ECTS')}")

#for outgoing, ingoing, data in G.edges(data=True):
#    print(f"{outgoing} -> {ingoing}: weight = {data.get('weight')}")

#for outgoing, ingoing, data in G.edges(data=True):
#    if "OR 3" in outgoing or "OR 3" in ingoing:
#        print(f"{outgoing} -> {ingoing}: weight = {data.get('weight')}")
# Out:
# FWS
# SSS
# Continuously
# FWS
# Continuously
# FWS
# FWS
# Continuously
# SSS
# FWS
# FWS
# SSS
# FWS
# SSS
# FWS
# FWS
# SSS
# FWS
# SSS
# SSS
# SSS
# FWS
# FWS
# SSS
# FWS
# SSS
# FWS
# Continuously
# Continuously
# SSS
# Continuously
# Continuously
# Continuously
# Continuously
# Continuously
# SSS
# SSS
# FWS
# FWS
# FWS
# FWS
# Continuously
# Continuously
# Continuously
# SSS
# FWS
# FWS
# SSS
# SSS
# FWS
# SSS
# FWS
# SSS
# SSS
# FWS
# Continuously
# FWS
# FWS
# SSS
# SSS
# FWS
# FWS
# SSS
# SSS
# FWS
# SSS
# FWS
# FWS
# FWS
# SSS
# FWS
# SSS
# FWS
# FWS
# SSS
# FWS
# SSS
# Continuously
# FWS
# SSS
# FWS
# SSS
# Continuously
# SSS
# SSS
# SSS
# SSS
# SSS
# SSS
# SSS
# FWS
# FWS
# SSS
# FWS
# FWS
# FWS
# FWS
# FWS
# FWS
# SSS
# SSS
# Continuously
# Continuously
# Continuously
# Continuously
# FWS
# FWS
# SSS
# Continuously
# FWS
# SSS
# SSS
# FWS
# FWS
# SSS
# SSS
# FWS
# SSS
# SSS
# FWS
# FWS
# FWS
# SSS
# SSS
# SSS
# FWS
# SSS
# FWS
# SSS
# SSS
# SSS
# FWS
# FWS
# FWS
# FWS
# SSS
# SSS
# SSS
# SSS
# FWS
# SSS
# FWS
# SSS
# FWS
# FWS
# SSS
# SSS
# SSS
# FWS
# SSS
# SSS
# FWS
# FWS
# FWS
# SSS
# FWS
# SSS
# FWS
# FWS
# SSS
# SSS
# SSS
# FWS
# FWS
# SSS
# FWS
# SSS
# SSS
# FWS
# SSS
# SSS
# Continuously
# Continuously
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
pos = nx.spring_layout(G, k=1) 

plt.figure(figsize=(12, 12))

node_colors = [G.nodes[node]['color'] for node in G.nodes()]

nx.draw(G, pos, with_labels=True, node_color=node_colors, font_size=3)

#nx.draw_networkx_labels(G, pos, labels=labels, font_size=10)
plt.savefig("graph.pdf", format="pdf") 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Wähle den gewünschten Node, z.B. node_id
node_id = 'ACC 510'  # Ersetze 'A' durch die ID des gewünschten Nodes
node_id = 'TP 500 Team Project Full'

# Finde die Knoten, die mit dem ausgewählten Knoten verbunden sind (eingehend und ausgehend)
incoming_nodes = [n for n in G.predecessors(node_id)]  # Eingehende Knoten
outgoing_nodes = [n for n in G.successors(node_id)]  # Ausgehende Knoten

# Alle relevanten Knoten: der Knoten selbst, eingehende und ausgehende Nachbarn
subgraph_nodes = set([node_id] + incoming_nodes + outgoing_nodes)
#subgraph_nodes = set([node_id] + outgoing_nodes)
#subgraph_nodes = set([node_id] + incoming_nodes)

# Erzeuge den Subgraphen mit den gefundenen Knoten
subgraph = G.subgraph(subgraph_nodes)

# Positionen der Nodes berechnen (für den Subgraphen)
pos = nx.circular_layout(subgraph)

plt.figure(figsize=(12, 12))

# Farben der Nodes für den Subgraphen
node_colors = [subgraph.nodes[node]['color'] for node in subgraph.nodes()]

# Zeichne den Subgraphen
nx.draw(subgraph, pos, with_labels=True, node_color=node_colors, font_size=12)

node_labels = {
    node: f"{node}\nAmount: {subgraph.nodes[node]['amount']}" 
    if 'amount' in subgraph.nodes[node] else node
    for node in subgraph.nodes()
}

offset = 0.05  # Verschiebung der Labels; kann angepasst werden
label_pos = {node: (pos[node][0], pos[node][1] + offset) for node in subgraph.nodes()}

# Zeichne die Labels mit den angepassten Positionen
nx.draw_networkx_labels(subgraph, label_pos, labels=node_labels, font_size=10)

edge_labels = nx.get_edge_attributes(subgraph, 'weight')
nx.draw_networkx_edge_labels(subgraph, pos, edge_labels=edge_labels)


# Speichere das Ergebnis und zeige es an
plt.savefig("subgraph_with_edges.pdf", format="pdf")
plt.show()

# %%
gc.createPools(G)

# %%
for node in G.nodes:
    if G.nodes[node].get("type") == "course":
        if G.nodes[node].get("pool") == None:
            print(node)

# %% [markdown]
# ### 2.3 Matching Graph Names to Database Names

# %%
#Match Course Names between Graph and Database

df_courseNames = pd.read_csv("../02_Ressources/DB_CourseNames.csv")

conn = sqlite3.connect('DB_CourseNames.db')
cursor = conn.cursor()

df_courseNames.to_sql('course_names', conn, if_exists='replace', index=False)

graph_courseNames = []
for course in courses:
    graph_courseNames.append(gc.mapGraphToDB_courseName(course))

matching_results = []

for graph_courseName in graph_courseNames:
    query = "SELECT kurs FROM course_names WHERE ? LIKE kurs || '%'" 
    cursor.execute(query, (graph_courseName,))
    results = cursor.fetchall()
    
    results_string = ', '.join([str(result[0]) for result in results])
    matching_results.append(graph_courseName + " matches: " + results_string)


query = "SELECT kurs FROM course_names" 
cursor.execute(query)
results = cursor.fetchall()
    

#for line in results:
#    print(line[0])

#print("\n")

for course_match in matching_results:
    #if re.match(r".*matches: $", course_match):
    print(course_match)

conn.close()
# Out:
# CS 500 Advanced Software Engineering matches: CS 500 Advanced Software Engineering
# CS 530 Database Systems II (DBSII) matches: CS 530 Database Systems II
# CS 550 Algorithmics matches: CS 550 Algorithmics
# CS 560 Large-Scale Data Management matches: CS 560 Large-Scale Data Management
# IE 500 Data Mining I matches: IE 500 Data Mining I
# IE 560 Decision Support matches: IE 560 Decision Support
# CS 600 Model Driven Development matches: CS 600 Model Driven Development
# CS 605 GPU Programming matches: CS 605 GPU Programming
# CS 646 Higher Level Computer Vision matches: CS 646 Higher Level Computer Vision
# CS 647 Image Processing matches: CS 647 Image Processing
# CS 651 Kryptographie II matches: CS 651 Kryptographie II
# CS 652 Data Security matches: CS 652 Data Security
# CS 654 Internet of Things Security matches: CS 654 Internet of Things Security
# IE 630 Query Optimization matches: IE 630 Query Optimization
# IE 650 Semantic Web Technologies matches: IE 650 Semantic Web Technologies
# IE 661 Text Analytics matches: IE 661 Text Analytics
# IE 663 Information Retrieval and Web Search matches: IE 663 Information Retrieval and Web Search
# IE 670 Web Data Integration matches: IE 670 Web Data Integration
# IE 671 Web Mining matches: IE 671 Web Mining
# IE 672 Data Mining II matches: IE 672 Data Mining II
# IE 674 Hot Topics in Machine Learning matches: IE 674 Hot Topics in Machine Learning
# IE 675 Machine Learning matches: IE 675 Machine Learning
# IE 676 Network Analysis matches: IE 676 Network Analysis
# IE 691 Information Retrieval Project matches: IE 691 Information Retrieval Project
# IE 683 Web Data Integration Project matches: IE 683 Web Data Integration Project
# IE 684 Web Mining Project matches: IE 684 Web Mining Project
# IE 689 Relational Learning matches: IE 689 Relational Learning
# TP 500 Team Project Full matches: TP 500 Team Project
# SQ 500 Scientific Research matches: SQ 500 Scientific Research
# CS 701 Selected Topics in Algorithmics and Cryptography matches: CS 701 Selected Topics in Algorithmics and Cryptography
# CS 704 Master Seminar Artificial Intelligence matches: CS 704 Master Seminar Artificial Intelligence
# CS 705 Datenbankseminar matches: CS 705 Datenbankseminar
# CS 707 Seminar Data and Web Science matches: CS 707 Seminar Data and Web Science
# CS 708 Seminar Software Engineering matches: CS 708 Seminar Software Engineering
# CS 709 Seminar Text Analytics matches: CS 709 Seminar Text Analytics
# CS 710 Seminar Selected Topics in Data Science matches: CS 710 Seminar Selected Topics in Data Science
# CS 715 Large-Scale Data Integration Seminar matches: CS 715 Large-Scale Data Integration Seminar
# CS 716 Seminar IT-Security matches: CS 716 Seminar IT-Security
# CS 717 Master Seminar on Computer Vision matches: CS 717 Master Seminar on Computer Vision
# CS 718 AI and Data Science in Fiction and Society matches: CS 718 AI and Data Science in Fiction and Society
# CS 719 Seminar on Process Analysis matches: CS 719 Seminar on Process Analysis
# IE 704 Seminar AI Systems Engineering matches: IE 704 Seminar AI Systems Engineering
# IS 712 Seminar matches: IS 712 Seminar
# MA 650 Master Thesis matches:
# ACC 510 Jahresabschluss matches: ACC 510 Jahresabschluss
# ACC 520 IFRS Reporting and Capital Markets matches: ACC 520 IFRS Reporting and Capital Markets
# ACC 530 Group Accounting matches: ACC 530 Group Accounting
# ACC 540 Financial Statement Analysis & Equity Valuation matches: ACC 540 Financial Statement Analysis & Equity Valuation
# ACC 560 Managerial Accounting matches:
# TAX 520 Besteuerung der Unternehmen matches: TAX 520 Besteuerung der Unternehmen
# TAX 521 Fallstudien zur Besteuerung der Unternehmen matches: TAX 521 Fallstudien zur Besteuerung der Unternehmen
# TAX 530 Taxation of Businesses and Individuals matches: TAX 530 Taxation of Businesses and Individuals
# ACC 620 Accounting for Financial Instruments & Financial Institutions matches: ACC 620 Accounting for Financial Instruments & Financial Institutions
# ACC 626 Transaction Accounting matches:
# ACC 628 Selected Issues in IFRS Accounting matches:
# ACC 632 Konzernrechnungslegungspraxis matches:
# ACC 662 Private Equity: Due Diligence and Value Creation matches:
# ACC 670 Audit Theory matches: ACC 670 Audit Theory
# ACC 676 Case Studies on Consulting in Financial Services Firms matches:
# ACC 680 Disclosure Theory matches:
# TAX 611 Fallstudien zur internationalen Unternehmensbesteuerung matches:
# TAX 620 Applied Empirical Research: Methods and Practical Implementation matches:
# TAX 630 International Business Taxation matches: TAX 630 International Business Taxation
# TAX 631 Internationale Konzernbesteuerung matches:
# TAX 660 Tax Planning: The Role of Taxes for Business Decisions matches: TAX 660 Tax Planning: The Role of Taxes for Business Decisions
# TAX 661 Case Studies in International Tax Planning matches:
# FIN 500 Investments matches: FIN 500 Investments
# FIN 540 Corporate Finance I - Lecture (Capital Structure, Cost of Capital and Valuation) matches: FIN 540 Corporate Finance I - Lecture (Capital Structure, Cost of Capital and Valuation)
# FIN 541 Corporate Finance I - Case Study (Capital Structure, Cost of Capital and Valuation) matches: FIN 541 Corporate Finance I - Case Study (Capital Structure, Cost of Capital and Valuation)
# FIN 542 Quantitative Corporate Finance for Researchers matches:
# FIN 560 Risikomanagement von Versicherungsunternehmen matches: FIN 560 Risikomanagement von Versicherungsunternehmen
# FIN 561 Investmentmanagement von Versicherungsunternehmen matches: FIN 561 Investmentmanagement von Versicherungsunternehmen
# FIN 580 Derivatives I - Basic Strategies and Pricing matches: FIN 580 Derivatives I - Basic Strategies and Pricing
# FIN 590 Financial Institutions I matches: FIN 590 Financial Institutions I
# FIN 601 Bond Markets matches: FIN 601 Bond Markets
# FIN 602 Trading and Exchanges matches: FIN 602 Trading and Exchanges
# FIN 603 Empirical Finance matches:
# FIN 604 Stata in Finance matches:
# FIN 605 Applied Portfolio Management matches:
# FIN 620 Behavioral Finance matches: FIN 620 Behavioral Finance
# FIN 630 Corporate Governance matches: FIN 630 Corporate Governance
# FIN 640 Corporate Finance II (Mergers, Acquisitions and Divestitures) matches:
# FIN 660 Quantitatives Risikomanagement matches: FIN 660 Quantitatives Risikomanagement
# FIN 682 International Asset Management matches: FIN 682 International Asset Management
# FIN 684 Financial Institutions II matches:
# FIN 685 Topics in Financial Regulation matches:
# FIN 686 Topics in Sustainable Finance matches:
# IS 510 Process Management matches: IS 510 Process Management
# IS 512 IT Management in the Digital Age matches: IS 512 IT Management in the Digital Age
# IS 513 Applied IT Management in the Digital Age matches: IS 513 Applied IT Management in the Digital Age
# IS 514 Process Mining and Analytics matches: IS 514 Process Mining and Analytics
# IS 540 Management of Enterprise Systems matches: IS 540 Management of Enterprise Systems
# IS 541 Theories and Methods in Information Systems matches: IS 541 Theories and Methods in Information Systems
# IS 553 System Software matches: IS 553 System Software
# IS 602 Business Intelligence and Business Analytics Systems matches: IS 602 Business Intelligence and Business Analytics Systems
# IS 607 Digital Innovation matches: IS 607 Digital Innovation
# IS 613 Applied Project in Design Thinking and Lean Software Development matches: IS 613 Applied Project in Design Thinking and Lean Software Development
# IS 614 Corporate Knowledge Management matches: IS 614 Corporate Knowledge Management
# IS 615 Design Thinking and Lean Development in Enterprise Software Development matches: IS 615 Design Thinking and Lean Development in Enterprise Software Development
# IS 621 Self-Organizing and Adaptive Systems matches: IS 621 Self-Organizing and Adaptive Systems
# IS 629 Agile Software Product Management and Design matches: IS 629 Agile Software Product Management and Design
# IS 712 Seminar matches: IS 712 Seminar
# IS 722 Seminar Trends in Distributed Systems matches: IS 722 Seminar Trends in Distributed Systems
# IS 742 Seminar Trends in Enterprise Systems matches: IS 742 Seminar Trends in Enterprise Systems
# IS 752 Seminar on Process and Management Analytics matches: IS 752 Seminar on Process and Management Analytics
# MAN 630 Introduction to Entrepreneurship matches: MAN 630 Introduction to Entrepreneurship
# MAN 631 Creativity and Entrepreneurship in Practice matches: MAN 631 Creativity and Entrepreneurship in Practice
# MAN 632 Advanced Entrepreneurship matches: MAN 632 Advanced Entrepreneurship
# MAN 633 Entrepreneurial Spirit matches: MAN 633 Entrepreneurial Spirit
# MAN 635 Social Entrepreneurship: Targeting Social Capital through Ecopreneurship matches: MAN 635 Social Entrepreneurship: Targeting Social Capital through Ecopreneurship
# MAN 636 International Entrepreneurship and Managing Change matches: MAN 636 International Entrepreneurship and Managing Change
# MAN 644 Human Resource Training and Development matches: MAN 644 Human Resource Training and Development
# MAN 645 Leadership and Motivation matches: MAN 645 Leadership and Motivation
# MAN 646 HR Analytics matches: MAN 646 HR Analytics
# MAN 647 Strategic and International Human Resource Management matches: MAN 647 Strategic and International Human Resource Management
# MAN 648 Incentives and Performance matches: MAN 648 Incentives and Performance
# MAN 649 Human Resource Recruitment and Selection matches: MAN 649 Human Resource Recruitment and Selection
# MAN 654 Corporate Restructuring matches: MAN 654 Corporate Restructuring
# MAN 655  Corporate Strategy: Managing Business Groups matches: MAN 655  Corporate Strategy: Managing Business Groups
# MAN 656 Mergers & Acquisitions matches: MAN 656 Mergers & Acquisitions
# MAN 657 Global Strategic Management matches: MAN 657 Global Strategic Management
# MAN 663 Digital Social Innovation Lab with SocEnt BW and SAP matches: MAN 663 Digital Social Innovation Lab with SocEnt BW and SAP
# MAN 664 Sustainability Games matches: MAN 664 Sustainability Games
# MAN 666 Alternative Modelle der Führungsethik matches:
# MAN 667 Social Impact Measurement matches: MAN 667 Social Impact Measurement
# MAN 675 Ausgewählte Herausforderungen im Nonprofit Management matches:
# MAN 676 Ausgewählte Herausforderungen im Public Management matches: MAN 676 Ausgewählte Herausforderungen im Public Management
# MAN 679 Eine wissenschaftliche Einführung in das Public und Nonprofit Management matches: MAN 679 Eine wissenschaftliche Einführung in das Public und Nonprofit Management
# MAN 680 Challenges of Public and Nonprofit Management – Case Study Seminar matches:
# MAN 690 Innovation Management matches: MAN 690 Innovation Management
# MAN 691 Selected Topics in Organizational Behavior matches: MAN 691 Selected Topics in Organizational Behavior
# MAN 692 Organisationstheorie matches: MAN 692 Organisationstheorie
# MAN 693 Strategic Intellectual Property Management matches: MAN 693 Strategic Intellectual Property Management
# MAN 695 Project Course Innovation Management matches:
# MKT 510 Price and Product Management matches: MKT 510 Price and Product Management
# MKT 511 Marketing Analytics matches: MKT 511 Marketing Analytics
# MKT 520 Market Research matches: MKT 520 Market Research
# MKT 531 Marketing Theory matches: MKT 531 Marketing Theory
# MKT 545 Customers, Markets and Firm Strategy matches: MKT 545 Customers, Markets and Firm Strategy
# MKT 560 Services Marketing matches: MKT 560 Services Marketing
# MKT 570 Marketing of Innovations matches: MKT 570 Marketing of Innovations
# MKT 580 Digital Marketing Strategy matches: MKT 580 Digital Marketing Strategy
# MKT 611 Sales Management and Customer Relationship Management matches: MKT 611 Sales Management and Customer Relationship Management
# MKT 612 Business-to-Business-Marketing matches: MKT 612 Business-to-Business-Marketing
# MKT 613 Verhandlungsführung matches: MKT 613 Verhandlungsführung
# MKT 614 Marketing Communication matches: MKT 614 Marketing Communication
# MKT 615 Sales Management matches: MKT 615 Sales Management
# MKT 622 Country Manager matches: MKT 622 Country Manager
# MKT 623 Strategic Marketing Management Simulation matches: MKT 623 Strategic Marketing Management Simulation
# MKT 661 Consumer Behavior matches: MKT 661 Consumer Behavior
# MKT 663 Branding and Brand Management matches: MKT 663 Branding and Brand Management
# MKT 664 Brand Strategy Seminar matches: MKT 664 Brand Strategy Seminar
# OPM 501 Logistics Management matches: OPM 501 Logistics Management
# OPM 502 Inventory Management matches: OPM 502 Inventory Management
# OPM 503 Transportation I - Land Transport and Shipping matches: OPM 503 Transportation I - Land Transport and Shipping
# OPM 504 Transportation II: Air Transport matches: OPM 504 Transportation II: Air Transport
# OPM 510 Sustainable Operations matches: OPM 510 Sustainable Operations
# OPM 544 Advanced Supply Chain Planning matches: OPM 544 Advanced Supply Chain Planning
# OPM 561 Production Management: Lean Approaches and Variability matches: OPM 561 Production Management: Lean Approaches and Variability
# OPM 562 Business Analytics: Applications of Artificial Intelligence for Data-Driven Decision Making matches:
# OPM 565 Integrierte Produktentwicklung matches: OPM 565 Integrierte Produktentwicklung
# OPM 581 Service Operations Management matches: OPM 581 Service Operations Management
# OPM 582 Case Studies in Service Operations Management matches: OPM 582 Case Studies in Service Operations Management
# OPM 591 Strategic Procurement matches: OPM 591 Strategic Procurement
# OPM 601 Supply Chain Management matches: OPM 601 Supply Chain Management
# OPM 661 Business Analytics: Robust Planning in Stochastic Systems matches: OPM 661 Business Analytics: Robust Planning in Stochastic Systems
# OPM 662 Business Analytics: Modeling and Optimization matches: OPM 662 Business Analytics: Modeling and Optimization
# OPM 682 Revenue Management matches: OPM 682 Revenue Management
# OPM 691 Supply Risk Management matches: OPM 691 Supply Risk Management
# OPM 692 Strategic Sourcing matches: OPM 692 Strategic Sourcing
# OPM 693 Sourcing Excellence matches:
# TP 500 Team Project Split 1 matches: TP 500 Team Project
# TP 500 Team Project Split 2 matches: TP 500 Team Project

# %% [markdown]
# ### 2.4 Weight Course -> Skill Edges

# %%
#Export graph to run weighting scripts externally
nx.write_graphml(G, "CourseSkillGraph_Master.graphml")

# %%
course_skill_weights_df = pd.read_excel("../04_Graph/CourseSkillWeights_Master.xlsx")
course_skill_weights = course_skill_weights_df.values.tolist()

for weight in course_skill_weights:
    G.edges[weight[1], weight[2]]["weight"] = weight[0]/100

# %%
#Adjust 0 weights for course suggestion algorithm

smallestWeight = 1000
for edge in G.edges:
    if G.nodes[edge[0]].get("type") == "course" and G.nodes[edge[1]].get("type") == "skill":
        weight = G.edges[edge].get("weight")
        if weight < smallestWeight and weight > 0:
            smallestWeight = weight

print(smallestWeight)
# Out:
# 0.001

# %%
#G.edges[("TP 500 Team Project Split 2","Scientific Work (SW)")]["weight"] = G.edges[("TP 500 Team Project", "Scientific Work (SW)")].get("weight")

# %%
#Export graph with course -> skill weights as needed for the skill -> course weighting script
nx.write_graphml(G, "CourseSkillGraph_Master.graphml")

# %% [markdown]
# ### 2.5 Weight Skill -> Course Edges

# %%
skill_course_weights_df = pd.read_excel("../04_Graph/SkillCourseWeights_Master.xlsx")
skill_course_weights = skill_course_weights_df.values.tolist()

for weight in skill_course_weights:
    G.edges[weight[1], weight[2]]["weight"] = weight[0]

# %%
#Export graph with course -> skill weights as needed for the skill -> course weighting script
nx.write_graphml(G, "CourseSkillGraph_Master.graphml")
